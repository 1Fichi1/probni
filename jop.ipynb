# %% [markdown]
# Практическая №5 Анализ датасета
# Цель: целью данного кода является базовый анализ датасета "Mall_Customers.csv". Производятся следующие шаги: вывод датасета, описание его структуры, обработка данных, проведение базового анализа с использованием функций библиотеки pandas, и сохранение обработанного датасета в новый файл.
# CustomerID: Уникальный идентификатор клиента.
# Genre: Пол клиента (Male - мужчина, Female - женщина).
# Age: Возраст клиента.
# Annual Income (k$): Годовой доход клиента в тысячах долларов.
# Spending Score (1-100): Оценка трат клиента в магазине, где 1 - низкий уровень трат, 100 - высокий уровень трат.

# %%
import pandas as pd
import numpy as np
Mall_Customers = pd.read_csv('Mall_Customers.csv')
Mall_Customers
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %% [markdown]
# Вывод:

# %%
Mall_Customers.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %% [markdown]
# размерность массива:

# %%
Mall_Customers.shape
# Out:
# (200, 5)

# %% [markdown]
# вывод намименований всех колонок:

# %%
Mall_Customers.columns
# Out:
# Index(['CustomerID', 'Genre', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %% [markdown]
# Вывод всех уникальных значений:

# %%
Mall_Customers['Spending Score (1-100)'].unique()
# Out:
# array([39, 81,  6, 77, 40, 76, 94,  3, 72, 14, 99, 15, 13, 79, 35, 66, 29,
#        98, 73,  5, 82, 32, 61, 31, 87,  4, 92, 17, 26, 75, 36, 28, 65, 55,
#        47, 42, 52, 60, 54, 45, 41, 50, 46, 51, 56, 59, 48, 49, 53, 44, 57,
#        58, 43, 91, 95, 11,  9, 34, 71, 88,  7, 10, 93, 12, 97, 74, 22, 90,
#        20, 16, 89,  1, 78, 83, 27, 63, 86, 69, 24, 68, 85, 23,  8, 18],
#       dtype=int64)

# %% [markdown]
# Отсортировка по определенным параметрам:

# %%
Mall_Customers.sort_values(by='CustomerID')
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %% [markdown]
# Удаление ненужных столбцов или строк:

# %%
Mall_Customers.drop(columns = ["Genre"], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 Mall_Customers.drop(columns = ["Genre"], inplace=True)
#
# File c:\Users\batyr\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# File c:\Users\batyr\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File c:\Users\batyr\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File c:\Users\batyr\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:7000, in Index.drop(self, labels, errors)
#    6998 if mask.any():
#    6999     if errors != "ignore":
# -> 7000         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7001     indexer = indexer[~mask]
#    7002 return self.delete(indexer)
#
# KeyError: "['Genre'] not found in axis"

# %% [markdown]
# Заменение определенных значений в датасете (например, пустые):

# %%
Mall_Customers["Age"] = Mall_Customers["Age"].replace(Mall_Customers["Age"].unique(), "immortal")
Mall_Customers
# Out:
#      CustomerID       Age  Annual Income (k$)  Spending Score (1-100)
# 0             1  immortal                  15                      39
# 1             2  immortal                  15                      81
# 2             3  immortal                  16                       6
# 3             4  immortal                  16                      77
# 4             5  immortal                  17                      40
# ..          ...       ...                 ...                     ...
# 195         196  immortal                 120                      79
# 196         197  immortal                 126                      28
# 197         198  immortal                 126                      74
# 198         199  immortal                 137                      18
# 199         200  immortal                 137                      83
#
# [200 rows x 4 columns]

# %% [markdown]
# Удаление дубликатов:

# %%
Mall_Customersa = Mall_Customers.drop_duplicates()
Mall_Customers
# Out:
#      CustomerID       Age  Annual Income (k$)  Spending Score (1-100)
# 0             1  immortal                  15                      39
# 1             2  immortal                  15                      81
# 2             3  immortal                  16                       6
# 3             4  immortal                  16                      77
# 4             5  immortal                  17                      40
# ..          ...       ...                 ...                     ...
# 195         196  immortal                 120                      79
# 196         197  immortal                 126                      28
# 197         198  immortal                 126                      74
# 198         199  immortal                 137                      18
# 199         200  immortal                 137                      83
#
# [200 rows x 4 columns]

# %% [markdown]
# Проведение анализов с помощью функций info:

# %%
Mall_Customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Age                     200 non-null    object
#  2   Annual Income (k$)      200 non-null    int64
#  3   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 6.4+ KB

# %% [markdown]
# Проведение анализа с помощью функций describe:

# %%
Mall_Customers.describe()
# Out:
#        CustomerID  Annual Income (k$)  Spending Score (1-100)
# count  200.000000          200.000000              200.000000
# mean   100.500000           60.560000               50.200000
# std     57.879185           26.264721               25.823522
# min      1.000000           15.000000                1.000000
# 25%     50.750000           41.500000               34.750000
# 50%    100.500000           61.500000               50.000000
# 75%    150.250000           78.000000               73.000000
# max    200.000000          137.000000               99.000000

# %% [markdown]
# Проведение выборки данных по строкам и столбцам с помощью loc:

# %%
subset = Mall_Customers.loc[[0, 1, 2], ['Annual Income (k$)', 'Spending Score (1-100)']]
subset
# Out:
#    Annual Income (k$)  Spending Score (1-100)
# 0                  15                      39
# 1                  15                      81
# 2                  16                       6

# %% [markdown]
# Сохранение нового датасета:

# %%
Mall_Customers.to_csv("Mall_Customers_NEW.csv", index=True)
Mall_Customers
# Out:
#      CustomerID       Age  Annual Income (k$)  Spending Score (1-100)
# 0             1  immortal                  15                      39
# 1             2  immortal                  15                      81
# 2             3  immortal                  16                       6
# 3             4  immortal                  16                      77
# 4             5  immortal                  17                      40
# ..          ...       ...                 ...                     ...
# 195         196  immortal                 120                      79
# 196         197  immortal                 126                      28
# 197         198  immortal                 126                      74
# 198         199  immortal                 137                      18
# 199         200  immortal                 137                      83
#
# [200 rows x 4 columns]

# %% [markdown]
# Вывод:
#
# В представленном коде был проведен базовый анализ датасета "Mall_Customers.csv" с использованием библиотеки pandas. В ходе анализа были выполнены следующие шаги:
#
# Выведены первые строки датасета для предварительного ознакомления с данными.
# Определена размерность массива данных.
# Проанализированы названия всех колонок и их смысл в контексте датасета.
# Выведены уникальные значения в выбранном столбце.
# Произведена сортировка данных по заданному параметру.
# Удален ненужный столбец "Genre".
# Значения в столбце "Age" заменены на "immortal".
# Удалены дубликаты.
# Проведен анализ данных с использованием функций info и describe.
# Выполнена выборка данных по строкам и столбцам с помощью loc.
# Новый обработанный датасет сохранен в файл "Mall_Customers_NEW.csv".
# В результате этих операций был получен обработанный и подготовленный датасет для дальнейших аналитических задач.
